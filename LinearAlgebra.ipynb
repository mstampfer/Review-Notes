# %% [markdown]
# ## Vectors
# Represented by both magnitude and direction.

# %% [markdown]
# $\overrightarrow{v} = (5,0) =
# \begin{align}
#     \begin{bmatrix}
#            5 \\
#            0
#          \end{bmatrix}
#   \end{align}
#   \in \mathbb{R}^2$

# %% [markdown]
# ### Sums of vectors
# $\overrightarrow{a} =
# \begin{align}
#     \begin{bmatrix}
#            6 \\
#            -2
#          \end{bmatrix}
#   \end{align} $
#
# $\overrightarrow{b} =
# \begin{align}
#     \begin{bmatrix}
#            -4 \\
#            4
#          \end{bmatrix}
#   \end{align}$
#
# $
# \overrightarrow{a} + \overrightarrow{b} =
# \begin{align}
#     \begin{bmatrix}
#            2 \\
#            2
#          \end{bmatrix}
#   \end{align} $

# %% [markdown]
# ### Scalar multiplication
#
# $\overrightarrow{a} =
# \begin{align}
#     \begin{bmatrix}
#            2 \\
#            1
#          \end{bmatrix}
#   \end{align}
#   $
#
# $3\overrightarrow{a} =  3
# \begin{align}
#     \begin{bmatrix}
#            2 \\
#            1
#          \end{bmatrix}
# =
#     \begin{bmatrix}
#            6 \\
#            3
#          \end{bmatrix}
#   \end{align} $

# %% [markdown]
# ### Unit vectors
#
# $\overrightarrow{i} =
# \begin{align}
#     \begin{bmatrix}
#            1 \\
#            0
#          \end{bmatrix}
#   \end{align} $
#
# $\overrightarrow{j} =
# \begin{align}
#     \begin{bmatrix}
#             0 \\
#             1
#          \end{bmatrix}
#   \end{align}$
#
# $
# \overrightarrow{a} =
# \begin{align}
#     \begin{bmatrix}
#            2 \\
#            2
#          \end{bmatrix}
#   \end{align}  = 2 \overrightarrow{i} + 2 \overrightarrow{j}$
#
#
#
#
# $\overrightarrow{b} =
# \begin{align}
#     \begin{bmatrix}
#            -4 \\
#            4
#          \end{bmatrix}
#   \end{align} = -4 \overrightarrow{i} + 4 \overrightarrow{j}$
#
#
# $\overrightarrow{a} + \overrightarrow{b} = 2 \overrightarrow{i} + 2 \overrightarrow{j}
# -4 \overrightarrow{i} + 4 \overrightarrow{j} = -2 \overrightarrow{i} + 6 \overrightarrow{j}
# $

# %% [markdown]
# ### Parametric representations of lines

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename="Screen Shot 1.png", width=400, height=400)

# %% [markdown]
# Find the equation for the line $L$ colinear with 2 vectors $\overrightarrow{a}$ and $\overrightarrow{b}$ in standard position
#
# $L=\left\{ \overrightarrow{b}+t\left(\vec{b}-\vec{a}\right)\left|t\epsilon\mathbb{R}\right.\right\} $
#
# $L=\left\{ \overrightarrow{a}+t\left(\vec{b}-\vec{a}\right)\left|t\epsilon\mathbb{R}\right.\right\} $
